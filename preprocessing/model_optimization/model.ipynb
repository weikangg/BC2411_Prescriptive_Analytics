# %%
import sys
from pathlib import Path
import pandas as pd
from datetime import datetime, timezone, timedelta


# replace with the actual filenames
_diets_df = pd.read_csv("processed_final_diets.csv")
_ex_df    = pd.read_csv("processed_final_exercises.csv")


print(f"Loaded {len(_diets_df)} diets and {len(_ex_df)} exercises")
# Out:
# Loaded 8293 diets and 93 exercises

# %%
def filter_diets(user_params: dict) -> pd.DataFrame:
    df = _diets_df.copy()
    dr = [d.lower() for d in user_params.get("dietRestrictions", [])]
    if "none" not in dr:
        df = df[df["diet_type"].str.lower().isin(dr)]
    vp = [v.lower() for v in user_params.get("varietyPreferences", [])]
    if "none" not in vp:
        df = df[df["cuisine_type"].str.lower().isin(vp)]
    print(f"Filtered diets ({len(df)} rows)")
    return df

def filter_exercises(user_params: dict) -> pd.DataFrame:
    df = _ex_df.copy()
    fl = user_params.get("fitnessLevel", "").lower()
    if fl and fl != "none":
        df = df[df["difficulty_level"].str.lower() == fl]
    pl = user_params.get("preferredLocation", "").lower()
    if pl and pl != "none":
        df = df[df["workout_location"].str.lower() == pl]
    wt = user_params.get("preferredWorkoutType", "").lower()
    if wt and wt != "none":
        df = df[df["activity_type"].str.lower() == wt]
    print(f"Filtered exercises ({len(df)} rows)")
    return df

# %%
from math import ceil


def compute_user_metrics(user: dict) -> dict:
    """Calculate user metrics based on personal information."""
    # Constants
    CALORIES_PER_KG = 7700  # Approximate calories per kg of body weight
    
    w, h, a = user["weight"], user["height"], user["age"]
    s = 5 if user["gender"].lower() == "male" else -161

    # 1. BMR
    bmr = 10 * w + 6.25 * h - 5 * a + s

    # 2. Activity multipliers (all lower-case keys)
    activity_map = {
        "Sedentary": 1.2,
        "Lightly Active": 1.375,
        "Moderately Active": 1.55,
        "Very Active": 1.725,
        "Extra Active": 1.9,
    }
    act = user["activityLevel"].lower()
    multiplier = activity_map.get(act, 1.2)
    tdee = bmr * multiplier

    # 3. Weight change & daily calorie delta
    gw = user["goalWeight"]
    wt_change = gw - w
    today = datetime.now(timezone.utc)
    tgt   = datetime.fromisoformat(user["goalTargetDate"].replace("Z","+00:00"))
    delta = tgt - today
    days = max( ceil(delta.total_seconds() / 86400), 1 )
    cal_delta = CALORIES_PER_KG * wt_change / days

    # 4. Target calories per day
    target_cal_pd = tdee + cal_delta

    return {
        "BMR": round(bmr,2),
        "TDEE": round(tdee,2),
        "weight_change_kg": round(wt_change,2),
        "days_to_target": days,
        "calorie_change_per_day": round(cal_delta,2),
        "target_calorie_per_day": round(target_cal_pd,2),
    }

# %%
# Example data sent from the mobile app
sample_user = {
    "activityLevel": "Moderately Active",
    "age": 35,
    "daysWeek": 3,
    "dietRestrictions": ["none"],
    "fitnessLevel": "intermediate",
    "freeTime": 3,
    "gender": "male",
    "goalTargetDate": "2025-05-15T04:48:00.000Z",
    "goalType": "weight_loss",
    "goalWeight": 65,
    "height": 175,
    "mealPrepTimePerDay": 80,
    "mealsPerDay": 3,
    "name": "wei",
    "preferredLocation": "none",
    "preferredWorkoutType": "none",
    "varietyPreferences": ["none"],
    "weight": 70
}

# %%
# filter data
diets_df = filter_diets(sample_user)
ex_df    = filter_exercises(sample_user)

# compute metrics
metrics = compute_user_metrics(sample_user)

# convert to lists of dicts for easy iteration in Gurobi
diet_options = diets_df.to_dict(orient="records")
ex_options   = ex_df.to_dict(orient="records")

print("User metrics:", metrics)
print(f"{len(diet_options)} diet options, {len(ex_options)} exercise options ready for modeling.")
# Out:
# Filtered diets (8293 rows)
# Filtered exercises (57 rows)
# User metrics: {'BMR': 1623.75, 'TDEE': 1948.5, 'weight_change_kg': -5, 'days_to_target': 32, 'calorie_change_per_day': -1203.12, 'target_calorie_per_day': 745.38}
# 8293 diet options, 57 exercise options ready for modeling.

# %%
print("Diet Dataset Preview:")
display(diets_df.head())
print(len(diets_df))
print("Exercise Dataset Preview:")
display(ex_df.head())
print(len(ex_df))
# Out:
# Diet Dataset Preview:
#                            recipe diet_type    cuisine_type  \
# 0     Chia And Blackberry Pudding      keto          kosher
# 1                Cinnamon Chiller      keto  south american
# 2          Cheesy Low-Carb Omelet      keto         chinese
# 3                      Angel Eggs      keto  middle eastern
# 4  Roasted Onions And Green Beans      keto         italian
#
#    total_time_in_minutes  calories   fat  carbs  protein
# 0                   45.0     437.0  38.0    8.0      8.0
# 1                   10.0     145.0   4.0    1.6      0.6
# 2                   10.0     451.0  36.0    3.0     33.0
# 3                   30.0     184.0  15.0    1.0     12.0
# 4                   25.0     214.0  19.4    3.7      8.3
# 8293
# Exercise Dataset Preview:
#        exercise_name  calories_burned_30min difficulty_level  \
# 0           Push-ups                    200     Intermediate
# 4  Mountain Climbers                    240     Intermediate
# 6   Bicycle Crunches                    210     Intermediate
# 7               Dips                    180     Intermediate
# 9     Russian Twists                    190     Intermediate
#
#    calories_burned_per_min workout_location activity_type
# 0                 6.666667             home       General
# 4                 8.000000             home       General
# 6                 7.000000             home       General
# 7                 6.000000             home       General
# 9                 6.333333             home       General
# 57

# %%
# More prep work
T = metrics["days_to_target"]
target_calorie_pd = metrics["target_calorie_per_day"]
goal = sample_user["goalType"].replace("_", " ")
# freeTime is in hours/day → convert to minutes/day
FT_day = sample_user["freeTime"] * 60
# mealPrepTimePerDay is total meal prep time (mins) per day
MPT_day = sample_user["mealPrepTimePerDay"] 
# meals per day
M = sample_user["mealsPerDay"]
# desired workout days per week
W = sample_user["daysWeek"]

num_weeks = T // 7
has_partial_week = T % 7 > 0

print(f"num_days:{T}")
print(f"num_weeks: {num_weeks}, has_partial_week: {has_partial_week}")
print(f"Goal: {goal}")
print(f"Free time per day: {FT_day} mins")
print(f"Total meal‐prep time per day: {MPT_day} mins")
print(f"Meals per day: {M}")
print(f"Workout days per week: {W}")
# Out:
# num_days:32
# num_weeks: 4, has_partial_week: True
# Goal: weight loss
# Free time per day: 180 mins
# Total meal‐prep time per day: 80 mins
# Meals per day: 3
# Workout days per week: 3

# %%
from gurobipy import Model, GRB, quicksum
model = Model("FitPlanner")
model.Params.OutputFlag = 0 # Turn off the display
model.setParam('TimeLimit', 300)  # Set time limit to 5 minutes

# Sets
days = range(T)
meals = list(diets_df.index)  # i in I
exercises = list(ex_df.index)  # j in J

# Parameters (extract from dataset)`
recipe = {i: diets_df.loc[i, 'recipe'] for i in meals}
cal = {i: diets_df.loc[i, 'calories'] for i in meals}
fat = {i: diets_df.loc[i, 'fat'] for i in meals}
carb = {i: diets_df.loc[i, 'carbs'] for i in meals}
protein = {i: diets_df.loc[i, 'protein'] for i in meals}
prep_time = {i: diets_df.loc[i, 'total_time_in_minutes'] for i in meals}
ex_name = {j: ex_df.loc[j, 'exercise_name'] for j in exercises}
location = {j: ex_df.loc[j, 'workout_location'] for j in exercises}
burn_rate = {j: ex_df.loc[j, 'calories_burned_per_min'] for j in exercises}
workout_type = {j: ex_df.loc[j, 'activity_type'] for j in exercises}

# Max time by workout type
max_time = {j: 60 if workout_type[j] in {"Sports"} else
            30 if workout_type[j] in {"Outdoor/Water"} else 20 for j in exercises}

# Variables
x = model.addVars(meals, days, vtype=GRB.BINARY, name="x")
y = model.addVars(exercises, days, vtype=GRB.BINARY, name="y")
t = model.addVars(exercises, days, vtype=GRB.CONTINUOUS, name="t")
s = model.addVars(days, vtype=GRB.BINARY, name="s")
Z = model.addVar(vtype=GRB.CONTINUOUS, name="Z")

# Objective: minimize deviation from target net calorie
model.setObjective(Z, GRB.MINIMIZE)

# Intake and burn
cal_intake = quicksum(x[i, d] * cal[i] for i in meals for d in days)
cal_burned = quicksum(t[j, d] * burn_rate[j] for j in exercises for d in days)

model.addConstr(Z >= cal_intake - cal_burned - T * target_calorie_pd)
model.addConstr(Z >= -(cal_intake - cal_burned - T * target_calorie_pd))

# Daily constraints
for d in days:
    intake_d = quicksum(x[i, d] * cal[i] for i in meals)
    burn_d = quicksum(t[j, d] * burn_rate[j] for j in exercises)
    prep_d = quicksum(x[i, d] * prep_time[i] for i in meals)
    exercise_d = quicksum(t[j, d] for j in exercises)

    # Calorie constraints based on goal
    if goal == "weight loss":
        model.addConstr(intake_d - burn_d <= target_calorie_pd)
    elif goal == "weight gain":
        model.addConstr(intake_d - burn_d >= target_calorie_pd)
    elif goal == "endurance":
        model.addConstr(intake_d - burn_d <= target_calorie_pd + 50)
        model.addConstr(intake_d - burn_d >= target_calorie_pd - 50)

    # Time constraints
    model.addConstr(prep_d <= MPT_day)
    model.addConstr(prep_d + exercise_d <= FT_day)

    # Meal count
    model.addConstr(quicksum(x[i, d] for i in meals) == M)

    # Link s[d] with exercise selection
    model.addConstr(s[d] <= quicksum(y[j, d] for j in exercises))
    model.addConstr(s[d] * 0.1 <= quicksum(y[j, d] for j in exercises))  # Added: If s[d]=1, at least one exercise
    
    for j in exercises:
        model.addConstr(t[j, d] <= y[j, d] * max_time[j])

    for i in meals:
        if d < T - 1:
            model.addConstr(x[i, d] + x[i, d + 1] <= 1)

    for j in exercises:
        if d < T - 1:
            model.addConstr(y[j, d] + y[j, d + 1] <= 1)

    # Macronutrient constraints
    fat_cal = quicksum(x[i, d] * fat[i] * 9 for i in meals)
    carb_cal = quicksum(x[i, d] * carb[i] * 4 for i in meals)
    protein_cal = quicksum(x[i, d] * protein[i] * 4 for i in meals)

    if goal in {"weight loss", "endurance"}:
        model.addConstr(fat_cal >= 0.2 * target_calorie_pd)
        model.addConstr(fat_cal <= 0.35 * target_calorie_pd)
        model.addConstr(carb_cal >= 0.45 * target_calorie_pd)
        model.addConstr(carb_cal <= 0.65 * target_calorie_pd)
        model.addConstr(protein_cal >= 0.1 * target_calorie_pd)
        model.addConstr(protein_cal <= 0.35 * target_calorie_pd)
    elif goal == "weight gain":
        model.addConstr(fat_cal >= 0.15 * target_calorie_pd)
        model.addConstr(fat_cal <= 0.3 * target_calorie_pd)
        model.addConstr(carb_cal >= 0.45 * target_calorie_pd)
        model.addConstr(carb_cal <= 0.6 * target_calorie_pd)
        model.addConstr(protein_cal >= 0.3 * target_calorie_pd)
        model.addConstr(protein_cal <= 0.35 * target_calorie_pd)

# Weekly workout constraint
for w in range(num_weeks):
    week_days = range(w * 7, (w + 1) * 7)
    model.addConstr(quicksum(s[d] for d in week_days) == W)

if has_partial_week:
    last_week_days = range(num_weeks * 7, T)
    model.addConstr(quicksum(s[d] for d in last_week_days) <= W)
    
# Optimize
model.optimize()

# Extract solution
if model.status == GRB.OPTIMAL or model.status == GRB.TIME_LIMIT:
    print(f"Solution found with objective value: {model.objVal}")
    
    today = datetime.now()
    week_net_calories = 0
    week_total_time = 0
    workout_time_week = 0
    workout_days_count = 0

    for d in days:
        current_date = today + timedelta(days=d)
        meals_d = [i for i in meals if x[i, d].x > 0.5]
        
        # Only include exercises with positive duration (t > 0)
        exercises_d = [(j, t[j, d].x) for j in exercises if t[j, d].x > 0.001]  # Using small threshold to account for floating point precision

        intake = sum(cal[i] for i in meals_d)
        burned = sum(t[j, d].x * burn_rate[j] for j, _ in exercises_d)
        net = intake - burned
        meal_prep_time = sum(prep_time[i] for i in meals_d)
        exercise_time = sum(time for _, time in exercises_d)
        total_time = meal_prep_time + exercise_time
        day_date = current_date

        week_net_calories += net
        week_total_time += total_time
        workout_time_week += exercise_time
        if len(exercises_d) > 0:
            workout_days_count += 1

        if d % 7 == 0:
            print(f"\n=== Week {(d // 7) + 1} ===")

        print(f"Day {d + 1} ({day_date.strftime('%Y-%m-%d')}):")

        print(" Selected Meals:")
        for i in meals_d:
            print(f"    - {recipe[i]}, calories:{cal[i]} cal, carb: {carb[i]}g, protein: {protein[i]}g, fat: {fat[i]}g, total time: {prep_time[i]} mins")

        print(" Selected Exercises:")
        if exercises_d:
            for j, time in exercises_d:
                print(f"    - {ex_name[j]}, type: {workout_type[j]}, location: {location[j]}, duration: {time:.1f} mins, estimated calories burned: {burn_rate[j] * time:.1f} cal")
        else:
            print("    - No exercises scheduled for this day")

        print(f"  Total Time Spent: {total_time:.1f} mins")
        print(f"  Total Net Calories: {net:.1f} kcal")

    
elif model.status == GRB.INFEASIBLE:
    print("Model is infeasible. Try relaxing some constraints.")
    # Compute and print the Irreducible Inconsistent Subsystem (IIS)
    model.computeIIS()
    print("The following constraints are causing the infeasibility:")
    for c in model.getConstrs():
        if c.IISConstr:
            print(f"  {c.ConstrName}")
elif model.status == GRB.UNBOUNDED:
    print("Model is unbounded.")
else:
    print(f"Optimization ended with status {model.status}")
# Out:
# Solution found with objective value: 0.0
#
# === Week 1 ===
# Day 1 (2025-04-13):
#  Selected Meals:
#     - The Ginger And Kale Ale, calories:140.0 cal, carb: 18.0g, protein: 1.0g, fat: 0.0g, total time: 5.0 mins
#     - Tropical Storm Glass, calories:186.0 cal, carb: 14.0g, protein: 1.0g, fat: 0.0g, total time: 5.0 mins
#     - Healthy & Delicious: Italian Egg-Drop Soup Recipe, calories:720.3675327719207 cal, carb: 84.14785911671517g, protein: 49.47829824683216g, fat: 20.65143370197016g, total time: 49.0 mins
#  Selected Exercises:
#     - Mountain Climbers, type: General, location: home, duration: 2.2 mins, estimated calories burned: 17.7 cal
#     - Leg Raises, type: General, location: home, duration: 20.0 mins, estimated calories burned: 123.3 cal
#     - Seated Rows, type: General, location: gym, duration: 20.0 mins, estimated calories burned: 160.0 cal
#   Total Time Spent: 101.2 mins
#   Total Net Calories: 745.4 kcal
# Day 2 (2025-04-14):
#  Selected Meals:
#     - A Melon Cucumber Medley, calories:112.0 cal, carb: 15.0g, protein: 2.0g, fat: 2.0g, total time: 5.0 mins
#     - Awesome Baby-Face Maker, calories:145.0 cal, carb: 14.0g, protein: 10.0g, fat: 1.0g, total time: 5.0 mins
#     - Mediterranean Pizza Pocket, calories:607.0344748494788 cal, carb: 78.12084762377752g, protein: 21.08417336845328g, fat: 23.35715454228395g, total time: 27.0 mins
#  Selected Exercises:
#     - Rollerblading/skating (Casual), type: Outdoor/Water, location: home, duration: 9.2 mins, estimated calories burned: 118.7 cal
#   Total Time Spent: 46.2 mins
#   Total Net Calories: 745.4 kcal
# Day 3 (2025-04-15):
#  Selected Meals:
#     - Aromatic Tea, calories:151.0 cal, carb: 0.0g, protein: 1.0g, fat: 0.0g, total time: 10.0 mins
#     - Emeril's Sazerac, calories:21.34 cal, carb: 5.2g, protein: 0.09g, fat: 0.02g, total time: 37.0 mins
#     - Butternut Penne with Feta and Pecans, calories:754.6647411694946 cal, carb: 113.12487929709263g, protein: 22.49515998446348g, fat: 23.57606489369667g, total time: 27.0 mins
#  Selected Exercises:
#     - Wrestling, type: Sports, location: home, duration: 25.2 mins, estimated calories burned: 181.6 cal
#   Total Time Spent: 99.2 mins
#   Total Net Calories: 745.4 kcal
# Day 4 (2025-04-16):
#  Selected Meals:
#     - Broccoli Egg Salad, calories:250.0 cal, carb: 5.6g, protein: 6.0g, fat: 11.0g, total time: 4.0 mins
#     - Roasted Garlic Mashed Potatoes recipes, calories:448.79 cal, carb: 63.62g, protein: 25.2g, fat: 10.39g, total time: 28.0 mins
#     - Herb-Infused Pisco Sour, calories:108.24 cal, carb: 23.82g, protein: 2.25g, fat: 0.44g, total time: 48.0 mins
#  Selected Exercises:
#     - Weight Lifting, type: Gym, location: gym, duration: 11.4 mins, estimated calories burned: 61.6 cal
#   Total Time Spent: 91.4 mins
#   Total Net Calories: 745.4 kcal
# Day 5 (2025-04-17):
#  Selected Meals:
#     - Dark Walnut Fudge, calories:134.0 cal, carb: 2.0g, protein: 2.0g, fat: 14.0g, total time: 10.0 mins
#     - Balanced Alkaline Veggie Cubes, calories:20.0 cal, carb: 5.0g, protein: 11.0g, fat: 0.2g, total time: 5.0 mins
#     - Stuffed Mediterranean Baked Potato, calories:651.2321575408646 cal, carb: 112.63721968341662g, protein: 23.620728530833343g, fat: 11.80004052042942g, total time: 60.0 mins
#  Selected Exercises:
#     - Calisthenics, type: Fitness, location: fitness corner, duration: 7.9 mins, estimated calories burned: 59.9 cal
#   Total Time Spent: 82.9 mins
#   Total Net Calories: 745.4 kcal
# Day 6 (2025-04-18):
#  Selected Meals:
#     - Sweet Kale Smoothie, calories:143.0 cal, carb: 12.0g, protein: 2.0g, fat: 1.0g, total time: 5.0 mins
#     - Mediterranean Pasta Salad, calories:526.05 cal, carb: 47.39g, protein: 31.63g, fat: 23.33g, total time: 34.0 mins
#     - Pasion Andina, calories:114.94 cal, carb: 27.55g, protein: 0.69g, fat: 0.22g, total time: 23.0 mins
#  Selected Exercises:
#     - Mountain Climbers, type: General, location: home, duration: 4.8 mins, estimated calories burned: 38.6 cal
#   Total Time Spent: 66.8 mins
#   Total Net Calories: 745.4 kcal
# Day 7 (2025-04-19):
#  Selected Meals:
#     - Green Olives With Deviled Eggs, calories:209.0 cal, carb: 0.2g, protein: 1.4g, fat: 8.0g, total time: 10.0 mins
#     - Classic Guacamole, calories:172.0 cal, carb: 11.0g, protein: 2.0g, fat: 15.0g, total time: 15.0 mins
#     - Mediterranean Kale Soup Recipe, calories:584.41 cal, carb: 99.83g, protein: 36.8g, fat: 4.21g, total time: 46.0 mins
#  Selected Exercises:
#     - Calisthenics, type: Fitness, location: fitness corner, duration: 20.0 mins, estimated calories burned: 152.0 cal
#     - Handball, type: Sports, location: sports centre, duration: 4.7 mins, estimated calories burned: 68.0 cal
#   Total Time Spent: 95.7 mins
#   Total Net Calories: 745.4 kcal
#
# === Week 2 ===
# Day 8 (2025-04-20):
#  Selected Meals:
#     - Mango Energizer, calories:136.0 cal, carb: 19.0g, protein: 5.0g, fat: 2.0g, total time: 5.0 mins
#     - Turkey Caesar Sandwich recipes, calories:414.34 cal, carb: 29.58g, protein: 30.13g, fat: 19.5g, total time: 51.0 mins
#     - Bloody Marys, calories:237.7 cal, carb: 42.54g, protein: 10.36g, fat: 2.9g, total time: 21.0 mins
#  Selected Exercises:
#     - Plyo Squats, type: General, location: home, duration: 4.1 mins, estimated calories burned: 42.7 cal
#   Total Time Spent: 81.1 mins
#   Total Net Calories: 745.4 kcal
# Day 9 (2025-04-21):
#  Selected Meals:
#     - Vegan Spiced Fat Bomb, calories:103.0 cal, carb: 4.0g, protein: 1.0g, fat: 10.0g, total time: 10.0 mins
#     - Thin Mint Smoothie, calories:287.64 cal, carb: 44.03g, protein: 5.29g, fat: 10.04g, total time: 41.0 mins
#     - Mediterranean Peasant Soup, calories:464.38 cal, carb: 72.91g, protein: 23.25g, fat: 8.86g, total time: 22.0 mins
#  Selected Exercises:
#     - Racquetball, type: Sports, location: sports centre, duration: 9.1 mins, estimated calories burned: 109.6 cal
#   Total Time Spent: 82.1 mins
#   Total Net Calories: 745.4 kcal
# Day 10 (2025-04-22):
#  Selected Meals:
#     - The Funky Skin Refresher, calories:103.0 cal, carb: 16.0g, protein: 4.0g, fat: 1.0g, total time: 5.0 mins
#     - Tasty Paleo Borscht, calories:635.0 cal, carb: 86.02g, protein: 15.58g, fat: 25.4g, total time: 37.0 mins
#     - The Manchester, calories:41.68 cal, carb: 10.42g, protein: 0.0g, fat: 0.0g, total time: 23.0 mins
#  Selected Exercises:
#     - Leg Raises, type: General, location: home, duration: 5.6 mins, estimated calories burned: 34.3 cal
#   Total Time Spent: 70.6 mins
#   Total Net Calories: 745.4 kcal
# Day 11 (2025-04-23):
#  Selected Meals:
#     - A Whole Melon Surprise, calories:134.0 cal, carb: 7.0g, protein: 3.0g, fat: 2.0g, total time: 5.0 mins
#     - Quinoa Salad with Pistachios and Currants, calories:653.4867554701046 cal, carb: 88.65178063579232g, protein: 18.270543464684767g, fat: 25.08860656313292g, total time: 44.0 mins
#     - Kerouac Cocktail, calories:34.9 cal, carb: 8.32g, protein: 0.18g, fat: 0.1g, total time: 25.0 mins
#  Selected Exercises:
#     - Calisthenics, type: Fitness, location: fitness corner, duration: 4.0 mins, estimated calories burned: 30.4 cal
#     - Horseback Riding, type: General, location: home, duration: 20.0 mins, estimated calories burned: 46.6 cal
#   Total Time Spent: 98.0 mins
#   Total Net Calories: 745.4 kcal
# Day 12 (2025-04-24):
#  Selected Meals:
#     - Grilled Fish Salad Nicoise, calories:194.0 cal, carb: 3.7g, protein: 0.5g, fat: 0.9g, total time: 10.0 mins
#     - Pisco Sour Recipe, calories:85.06 cal, carb: 18.13g, protein: 3.0g, fat: 0.06g, total time: 26.0 mins
#     - Fal Harvest Quinoa Salad, calories:637.2045262696856 cal, carb: 88.90806284497424g, protein: 16.15074793784132g, fat: 24.107698126491496g, total time: 34.0 mins
#  Selected Exercises:
#     - Push-ups, type: General, location: home, duration: 20.0 mins, estimated calories burned: 133.3 cal
#     - Mountain Climbers, type: General, location: home, duration: 4.7 mins, estimated calories burned: 37.6 cal
#   Total Time Spent: 94.7 mins
#   Total Net Calories: 745.4 kcal
# Day 13 (2025-04-25):
#  Selected Meals:
#     - Cilantro And Citrus Glass, calories:75.0 cal, carb: 16.0g, protein: 3.0g, fat: 1.0g, total time: 5.0 mins
#     - Coconut Oil Baked Spaghetti Squash Recipe [Paleo, AIP, Keto], calories:267.12 cal, carb: 27.92g, protein: 2.59g, fat: 16.12g, total time: 22.0 mins
#     - Mediterranean Peasant Soup, calories:464.38 cal, carb: 72.91g, protein: 23.25g, fat: 8.86g, total time: 22.0 mins
#  Selected Exercises:
#     - Shoulder Press, type: General, location: gym, duration: 8.0 mins, estimated calories burned: 61.1 cal
#   Total Time Spent: 57.0 mins
#   Total Net Calories: 745.4 kcal
# Day 14 (2025-04-26):
#  Selected Meals:
#     - Hearty Sweet Basil, calories:100.0 cal, carb: 19.0g, protein: 3.0g, fat: 1.0g, total time: 5.0 mins
#     - Veggie Frittata Breakfast Sandwiches, calories:621.69814320869 cal, carb: 62.65896129429812g, protein: 38.35207729587694g, fat: 24.183776538665533g, total time: 46.0 mins
#     - The Manchester, calories:41.68 cal, carb: 10.42g, protein: 0.0g, fat: 0.0g, total time: 23.0 mins
#  Selected Exercises:
#     - Bench Press, type: General, location: gym, duration: 1.9 mins, estimated calories burned: 18.0 cal
#   Total Time Spent: 75.9 mins
#   Total Net Calories: 745.4 kcal
#
# === Week 3 ===
# Day 15 (2025-04-27):
#  Selected Meals:
#     - Cilantro And Citrus Glass, calories:75.0 cal, carb: 16.0g, protein: 3.0g, fat: 1.0g, total time: 5.0 mins
#     - Mediterranean Warm Partridge Salad, calories:741.2489265991052 cal, carb: 83.3272550950221g, protein: 40.864854531493854g, fat: 27.16449867700459g, total time: 21.0 mins
#     - Ginger-Champagne Cocktail, calories:26.33 cal, carb: 6.24g, protein: 0.23g, fat: 0.05g, total time: 48.0 mins
#  Selected Exercises:
#     - Handball, type: Sports, location: sports centre, duration: 6.7 mins, estimated calories burned: 97.2 cal
#   Total Time Spent: 80.7 mins
#   Total Net Calories: 745.4 kcal
# Day 16 (2025-04-28):
#  Selected Meals:
#     - Awesome Fish Curry, calories:200.0 cal, carb: 23.0g, protein: 1.0g, fat: 10.0g, total time: 10.0 mins
#     - Cabbage Orange Salad, calories:348.77 cal, carb: 47.48g, protein: 7.29g, fat: 14.41g, total time: 22.0 mins
#     - Bloody Marys, calories:237.7 cal, carb: 42.54g, protein: 10.36g, fat: 2.9g, total time: 21.0 mins
#  Selected Exercises:
#     - Frisbee, type: General, location: home, duration: 11.7 mins, estimated calories burned: 41.1 cal
#   Total Time Spent: 64.7 mins
#   Total Net Calories: 745.4 kcal
# Day 17 (2025-04-29):
#  Selected Meals:
#     - Cilantro And Citrus Glass, calories:75.0 cal, carb: 16.0g, protein: 3.0g, fat: 1.0g, total time: 5.0 mins
#     - One-Pot Greek Pasta, calories:671.2502620477505 cal, carb: 98.53266040141594g, protein: 26.677712513158426g, fat: 18.93430782105035g, total time: 30.0 mins
#     - The Red Snapper from the King Cole Bar recipes, calories:15.85 cal, carb: 2.84g, protein: 0.56g, fat: 0.25g, total time: 23.0 mins
#  Selected Exercises:
#     - Wrestling, type: Sports, location: home, duration: 2.3 mins, estimated calories burned: 16.7 cal
#   Total Time Spent: 60.3 mins
#   Total Net Calories: 745.4 kcal
# Day 18 (2025-04-30):
#  Selected Meals:
#     - Broccoli Egg Salad, calories:250.0 cal, carb: 5.6g, protein: 6.0g, fat: 11.0g, total time: 4.0 mins
#     - Big Batch Mediterranean Herb Rub, calories:205.01 cal, carb: 31.85g, protein: 9.75g, fat: 4.29g, total time: 36.0 mins
#     - Cantaloupe & Green Tomato Salad, calories:358.08 cal, carb: 59.6g, protein: 7.87g, fat: 9.8g, total time: 23.0 mins
#  Selected Exercises:
#     - Bear Crawls, type: General, location: home, duration: 9.2 mins, estimated calories burned: 67.7 cal
#   Total Time Spent: 72.2 mins
#   Total Net Calories: 745.4 kcal
# Day 19 (2025-05-01):
#  Selected Meals:
#     - The Savior Of Skin, calories:143.0 cal, carb: 19.0g, protein: 4.0g, fat: 1.0g, total time: 5.0 mins
#     - Mediterranean Capriata, calories:650.622729328244 cal, carb: 76.6804396207017g, protein: 26.47726374966275g, fat: 26.44354620519845g, total time: 45.0 mins
#     - Midnight Ride Cocktail Recipe, calories:58.05 cal, carb: 13.62g, protein: 0.51g, fat: 0.17g, total time: 29.0 mins
#  Selected Exercises:
#     - Wrestling, type: Sports, location: home, duration: 14.8 mins, estimated calories burned: 106.3 cal
#   Total Time Spent: 93.8 mins
#   Total Net Calories: 745.4 kcal
# Day 20 (2025-05-02):
#  Selected Meals:
#     - Balsamic Grilled Zucchini, calories:76.0 cal, carb: 5.0g, protein: 6.0g, fat: 5.0g, total time: 10.0 mins
#     - Generous Mango Surprise, calories:72.0 cal, carb: 17.0g, protein: 1.0g, fat: 0.0g, total time: 5.0 mins
#     - Four-Cheese Baked Penne, calories:699.7323184277539 cal, carb: 86.25389939465295g, protein: 37.0337305934172g, fat: 22.95353316394148g, total time: 49.0 mins
#  Selected Exercises:
#     - Reverse Lunges, type: General, location: home, duration: 11.4 mins, estimated calories burned: 102.4 cal
#   Total Time Spent: 75.4 mins
#   Total Net Calories: 745.4 kcal
# Day 21 (2025-05-03):
#  Selected Meals:
#     - Crab Cakes With Green Onion And Mustard, calories:331.51 cal, carb: 17.16g, protein: 49.36g, fat: 7.27g, total time: 33.0 mins
#     - Piping Plum Recipe, calories:81.41000000000001 cal, carb: 20.01g, protein: 0.05g, fat: 0.13g, total time: 21.0 mins
#     - Cabbage Orange Salad, calories:348.77 cal, carb: 47.48g, protein: 7.29g, fat: 14.41g, total time: 22.0 mins
#  Selected Exercises:
#     - Elliptical Trainer, type: Cardio, location: gym, duration: 1.5 mins, estimated calories burned: 16.3 cal
#   Total Time Spent: 77.5 mins
#   Total Net Calories: 745.4 kcal
#
# === Week 4 ===
# Day 22 (2025-05-04):
#  Selected Meals:
#     - Green Olives With Deviled Eggs, calories:209.0 cal, carb: 0.2g, protein: 1.4g, fat: 8.0g, total time: 10.0 mins
#     - Turkey Bacon Garlic Knots, calories:27.0 cal, carb: 0.5g, protein: 0.5g, fat: 2.0g, total time: 25.0 mins
#     - Mediterranean Ratatouille Chicken, calories:637.7714758209025 cal, carb: 89.42971577658447g, protein: 39.22256576340145g, fat: 13.684705517884318g, total time: 36.0 mins
#  Selected Exercises:
#     - Rows, type: General, location: gym, duration: 14.8 mins, estimated calories burned: 128.4 cal
#   Total Time Spent: 85.8 mins
#   Total Net Calories: 745.4 kcal
# Day 23 (2025-05-05):
#  Selected Meals:
#     - Morning Aloha Smoothie, calories:121.0 cal, carb: 14.0g, protein: 1.0g, fat: 6.0g, total time: 5.0 mins
#     - Hearty Vegetable Stock (Vegan) Recipe, calories:13.56 cal, carb: 2.66g, protein: 0.46g, fat: 0.12g, total time: 26.0 mins
#     - Healthy & Delicious: Italian Egg-Drop Soup Recipe, calories:720.3675327719207 cal, carb: 84.14785911671517g, protein: 49.47829824683216g, fat: 20.65143370197016g, total time: 49.0 mins
#  Selected Exercises:
#     - Wrestling, type: Sports, location: home, duration: 15.2 mins, estimated calories burned: 109.5 cal
#   Total Time Spent: 95.2 mins
#   Total Net Calories: 745.4 kcal
# Day 24 (2025-05-06):
#  Selected Meals:
#     - Turkey Bacon Garlic Knots, calories:27.0 cal, carb: 0.5g, protein: 0.5g, fat: 2.0g, total time: 25.0 mins
#     - Spicy, Smoky Bean Cakes with Lime Slaw and Charred Avocado Recipe, calories:714.5988722655937 cal, carb: 93.69743742043704g, protein: 24.927124991363257g, fat: 26.677846957599176g, total time: 20.0 mins
#     - Bourbon Renewal Recipe, calories:81.28999999999999 cal, carb: 19.7g, protein: 0.33g, fat: 0.13g, total time: 32.0 mins
#  Selected Exercises:
#     - Softball, type: General, location: home, duration: 13.1 mins, estimated calories burned: 77.5 cal
#   Total Time Spent: 90.1 mins
#   Total Net Calories: 745.4 kcal
# Day 25 (2025-05-07):
#  Selected Meals:
#     - A Whole Melon Surprise, calories:134.0 cal, carb: 7.0g, protein: 3.0g, fat: 2.0g, total time: 5.0 mins
#     - Paleo Dirty Rice, calories:427.3 cal, carb: 49.41g, protein: 16.24g, fat: 18.3g, total time: 22.0 mins
#     - The Pink Drink, calories:227.52 cal, carb: 52.66g, protein: 2.87g, fat: 0.6g, total time: 24.0 mins
#  Selected Exercises:
#     - Russian Twists, type: General, location: home, duration: 6.9 mins, estimated calories burned: 43.4 cal
#   Total Time Spent: 57.9 mins
#   Total Net Calories: 745.4 kcal
# Day 26 (2025-05-08):
#  Selected Meals:
#     - Spring Soup With Poached Egg, calories:150.0 cal, carb: 12.0g, protein: 16.0g, fat: 5.0g, total time: 25.0 mins
#     - Generous Mango Surprise, calories:72.0 cal, carb: 17.0g, protein: 1.0g, fat: 0.0g, total time: 5.0 mins
#     - Ian's Vegan Chili, calories:618.2258369043216 cal, carb: 91.40460260461673g, protein: 24.826632345133188g, fat: 17.033433011702442g, total time: 50.0 mins
#  Selected Exercises:
#     - Mountain Climbers, type: General, location: home, duration: 11.9 mins, estimated calories burned: 94.8 cal
#   Total Time Spent: 91.9 mins
#   Total Net Calories: 745.4 kcal
# Day 27 (2025-05-09):
#  Selected Meals:
#     - Salmon Fat Bombs, calories:48.0 cal, carb: nang, protein: 0.5g, fat: 4.0g, total time: 10.0 mins
#     - Mediterranean Slow-Cooker Chicken Noodle Soup, calories:652.7161948068618 cal, carb: 67.85758624321424g, protein: 62.56675769459362g, fat: 14.557646561736712g, total time: 28.0 mins
#     - El Guapo Cocktail Recipe With Mezcal recipes, calories:85.14999999999999 cal, carb: 20.54g, protein: 0.5g, fat: 0.11g, total time: 38.0 mins
#  Selected Exercises:
#     - Lateral Raises, type: General, location: gym, duration: 7.4 mins, estimated calories burned: 40.5 cal
#   Total Time Spent: 83.4 mins
#   Total Net Calories: 745.4 kcal
# Day 28 (2025-05-10):
#  Selected Meals:
#     - Green Skinny Energizer, calories:300.0 cal, carb: 16.0g, protein: 10.0g, fat: 13.0g, total time: 5.0 mins
#     - Classic Sazerac, calories:0.24 cal, carb: 0.06g, protein: 0.0g, fat: 0.0g, total time: 31.0 mins
#     - 'Bella Asada Fajitas, calories:522.9300000000001 cal, carb: 85.11g, protein: 12.39g, fat: 14.77g, total time: 20.0 mins
#  Selected Exercises:
#     - Push-ups, type: General, location: home, duration: 11.7 mins, estimated calories burned: 77.8 cal
#   Total Time Spent: 67.7 mins
#   Total Net Calories: 745.4 kcal
#
# === Week 5 ===
# Day 29 (2025-05-11):
#  Selected Meals:
#     - Salted Macadamia Choco Smoothie, calories:165.0 cal, carb: 1.0g, protein: 12.0g, fat: 2.0g, total time: 5.0 mins
#     - Dill Butternut Squash Fries, calories:516.94 cal, carb: 89.2g, protein: 7.68g, fat: 14.38g, total time: 48.0 mins
#     - Pan-Seared Shrimp with Rosemary Spaghetti Squash, calories:311.14 cal, carb: 16.92g, protein: 36.25g, fat: 10.94g, total time: 20.0 mins
#  Selected Exercises:
#     - Mountain Climbers, type: General, location: home, duration: 11.0 mins, estimated calories burned: 87.7 cal
#     - Seated Rows, type: General, location: gym, duration: 20.0 mins, estimated calories burned: 160.0 cal
#   Total Time Spent: 104.0 mins
#   Total Net Calories: 745.4 kcal
# Day 30 (2025-05-12):
#  Selected Meals:
#     - Leeks And Broccoli Cucumber Glass, calories:219.0 cal, carb: 6.0g, protein: 4.0g, fat: 6.0g, total time: 5.0 mins
#     - Chickpeas With Spring Greens (Vegan), calories:647.9915287062094 cal, carb: 98.88239875571644g, protein: 27.677727763966733g, fat: 15.750113625275183g, total time: 32.0 mins
#     - Champs-lyses Cocktail, calories:32.52 cal, carb: 7.86g, protein: 0.09g, fat: 0.08g, total time: 43.0 mins
#  Selected Exercises:
#     - Shoulder Press, type: General, location: gym, duration: 20.0 mins, estimated calories burned: 153.3 cal
#     - Aerobics, type: Fitness, location: home, duration: 0.1 mins, estimated calories burned: 0.8 cal
#   Total Time Spent: 100.1 mins
#   Total Net Calories: 745.4 kcal
# Day 31 (2025-05-13):
#  Selected Meals:
#     - Chicken And Mushroom Stew, calories:247.0 cal, carb: 10.0g, protein: 24.0g, fat: 13.0g, total time: 40.0 mins
#     - Sweet Kale Smoothie, calories:143.0 cal, carb: 12.0g, protein: 2.0g, fat: 1.0g, total time: 5.0 mins
#     - Mediterranean Peasant Soup, calories:464.38 cal, carb: 72.91g, protein: 23.25g, fat: 8.86g, total time: 22.0 mins
#  Selected Exercises:
#     - Hockey, type: Sports, location: sports centre, duration: 11.4 mins, estimated calories burned: 109.0 cal
#   Total Time Spent: 78.4 mins
#   Total Net Calories: 745.4 kcal
# Day 32 (2025-05-14):
#  Selected Meals:
#     - Cumin And Salmon Meal, calories:300.0 cal, carb: 5.0g, protein: 20.0g, fat: 14.0g, total time: 10.0 mins
#     - Cinnamon and Honey Roasted Walnuts recipes, calories:245.6 cal, carb: 54.56g, protein: 0.9g, fat: 2.64g, total time: 24.0 mins
#     - Vegan Bistro Lunch Box, calories:222.6 cal, carb: 28.23g, protein: 8.25g, fat: 8.52g, total time: 39.0 mins
#  Selected Exercises:
#     - Water Volleyball, type: Sports, location: pool/sports facility, duration: 6.3 mins, estimated calories burned: 22.8 cal
#   Total Time Spent: 79.3 mins
#   Total Net Calories: 745.4 kcal

# %%
def diagnose_model(diets_df, ex_df, user_params, metrics):
    """
    Comprehensive diagnostic tool for the diet and exercise model.
    """
    print("\n=== MODEL DIAGNOSTICS ===\n")
    
    # 1. Check basic parameters
    T = metrics["days_to_target"]
    target_calorie_pd = metrics["target_calorie_per_day"]
    MPT_day = user_params["mealPrepTimePerDay"]
    FT_day = user_params["freeTime"] * 60
    M = user_params["mealsPerDay"]
    
    print(f"Planning horizon: {T} days")
    print(f"Target calories per day: {target_calorie_pd:.2f}")
    print(f"Meal prep time: {MPT_day} minutes")
    print(f"Free time: {FT_day} minutes")
    print(f"Meals per day: {M}")
    
    # 2. Check diet options
    print("\n--- Diet Options Analysis ---")
    print(f"Total diet options: {len(diets_df)}")
    
    # Time constraints
    avg_meal_time = diets_df['total_time_in_minutes'].mean()
    max_meal_time = diets_df['total_time_in_minutes'].max()
    min_meal_time = diets_df['total_time_in_minutes'].min()
    
    print(f"Average meal prep time: {avg_meal_time:.2f} minutes")
    print(f"Max meal prep time: {max_meal_time} minutes")
    print(f"Min meal prep time: {min_meal_time} minutes")
    
    # Check if meal prep time is feasible
    total_min_prep_time = min_meal_time * M
    if total_min_prep_time > MPT_day:
        print(f"⚠️ WARNING: Even the fastest {M} meals require {total_min_prep_time} minutes, but only {MPT_day} minutes available")
    
    # Calorie distribution
    avg_calories = diets_df['calories'].mean()
    max_calories = diets_df['calories'].max()
    min_calories = diets_df['calories'].min()
    
    print(f"Average meal calories: {avg_calories:.2f}")
    print(f"Max meal calories: {max_calories}")
    print(f"Min meal calories: {min_calories}")
    
    # Check if calorie target is feasible
    min_daily_calories = min_calories * M
    max_daily_calories = max_calories * M
    print(f"Min possible daily calories: {min_daily_calories}")
    print(f"Max possible daily calories: {max_daily_calories}")
    
    if target_calorie_pd < min_daily_calories:
        print(f"⚠️ WARNING: Target calories ({target_calorie_pd:.2f}) is less than minimum possible ({min_daily_calories})")
    if target_calorie_pd > max_daily_calories:
        print(f"⚠️ WARNING: Target calories ({target_calorie_pd:.2f}) is more than maximum possible ({max_daily_calories})")
    
    # Macronutrient analysis
    print("\n--- Macronutrient Analysis ---")
    
    # Calculate average macronutrient distribution
    avg_fat_cal = diets_df['fat'].mean() * 9
    avg_carb_cal = diets_df['carbs'].mean() * 4
    avg_protein_cal = diets_df['protein'].mean() * 4
    avg_total_cal = avg_fat_cal + avg_carb_cal + avg_protein_cal
    
    print(f"Average fat: {avg_fat_cal/avg_total_cal:.1%}")
    print(f"Average carbs: {avg_carb_cal/avg_total_cal:.1%}")
    print(f"Average protein: {avg_protein_cal/avg_total_cal:.1%}")
    
    # Check macronutrient constraints
    goal = user_params["goalType"]
    
    if goal in {"weight_loss", "endurance"}:
        fat_min, fat_max = 0.2, 0.35
        carb_min, carb_max = 0.45, 0.65
        protein_min, protein_max = 0.1, 0.35
    else:  # weight_gain
        fat_min, fat_max = 0.15, 0.3
        carb_min, carb_max = 0.45, 0.6
        protein_min, protein_max = 0.3, 0.35
    
    print(f"\nRequired macronutrient ranges for {goal}:")
    print(f"Fat: {fat_min:.1%} - {fat_max:.1%}")
    print(f"Carbs: {carb_min:.1%} - {carb_max:.1%}")
    print(f"Protein: {protein_min:.1%} - {protein_max:.1%}")
    
    # Check if any meals satisfy the macronutrient constraints
    meals_in_range = 0
    for _, meal in diets_df.iterrows():
        fat_cal = meal['fat'] * 9
        carb_cal = meal['carbs'] * 4
        protein_cal = meal['protein'] * 4
        total_cal = fat_cal + carb_cal + protein_cal
        
        fat_pct = fat_cal / total_cal
        carb_pct = carb_cal / total_cal
        protein_pct = protein_cal / total_cal
        
        if (fat_min <= fat_pct <= fat_max and 
            carb_min <= carb_pct <= carb_max and 
            protein_min <= protein_pct <= protein_max):
            meals_in_range += 1
    
    print(f"\nMeals satisfying macronutrient constraints: {meals_in_range} out of {len(diets_df)}")
    if meals_in_range < M:
        print(f"⚠️ WARNING: Not enough meals satisfy macronutrient constraints for {M} meals per day")
    
    # 3. Check exercise options
    print("\n--- Exercise Options Analysis ---")
    print(f"Total exercise options: {len(ex_df)}")
    
    # Calorie burn analysis
    avg_burn_rate = ex_df['calories_burned_per_min'].mean()
    max_burn_rate = ex_df['calories_burned_per_min'].max()
    min_burn_rate = ex_df['calories_burned_per_min'].min()
    
    print(f"Average burn rate: {avg_burn_rate:.2f} cal/min")
    print(f"Max burn rate: {max_burn_rate:.2f} cal/min")
    print(f"Min burn rate: {min_burn_rate:.2f} cal/min")
    
    # 4. Suggested relaxations
    print("\n--- Suggested Relaxations ---")
    
    if total_min_prep_time > MPT_day:
        print("1. Increase meal prep time or reduce meals per day")
    
    if target_calorie_pd < min_daily_calories or target_calorie_pd > max_daily_calories:
        print("2. Adjust target calories or add more diverse meal options")
    
    if meals_in_range < M:
        print("3. Relax macronutrient constraints or add more diverse meal options")
    
    print("4. Consider relaxing the food variation constraint (no same food on consecutive days)")
    print("5. Consider relaxing the exercise variation constraint")
    
    return {
        "meal_time_feasible": total_min_prep_time <= MPT_day,
        "calorie_target_feasible": min_daily_calories <= target_calorie_pd <= max_daily_calories,
        "macronutrient_feasible": meals_in_range >= M
    }

# Use this function before running the optimization
diagnostic_results = diagnose_model(diets_df, ex_df, sample_user, metrics)
# Out:
# === MODEL DIAGNOSTICS ===
#
# Planning horizon: 32 days
# Target calories per day: 745.38
# Meal prep time: 80 minutes
# Free time: 300 minutes
# Meals per day: 1
#
# --- Diet Options Analysis ---
# Total diet options: 8293
# Average meal prep time: 39.85 minutes
# Max meal prep time: 630.0 minutes
# Min meal prep time: 0.0 minutes
# Average meal calories: 619.85
# Max meal calories: 880.0
# Min meal calories: 0.24
# Min possible daily calories: 0.24
# Max possible daily calories: 880.0
#
# --- Macronutrient Analysis ---
# Average fat: 51.4%
# Average carbs: 31.0%
# Average protein: 17.5%
#
# Required macronutrient ranges for weight_loss:
# Fat: 20.0% - 35.0%
# Carbs: 45.0% - 65.0%
# Protein: 10.0% - 35.0%
#
# Meals satisfying macronutrient constraints: 645 out of 8293
#
# --- Exercise Options Analysis ---
# Total exercise options: 57
# Average burn rate: 7.70 cal/min
# Max burn rate: 14.40 cal/min
# Min burn rate: 2.33 cal/min
#
# --- Suggested Relaxations ---
# 4. Consider relaxing the food variation constraint (no same food on consecutive days)
# 5. Consider relaxing the exercise variation constraint
