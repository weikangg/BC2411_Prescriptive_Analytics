# %%
import pandas as pd
import matplotlib.pyplot as plt

# Enable inline plotting (if using Jupyter Notebook)
# %matplotlib inline

# Load the final merged dataset.
# Adjust the file path as needed – here, we assume it is in the current working directory.
df = pd.read_csv('../../data/final/processed_final_diets.csv')

# Display the first few rows
df.head()
# Out:
#                            recipe diet_type    cuisine_type  \
# 0     Chia And Blackberry Pudding      keto         italian
# 1                Cinnamon Chiller      keto        american
# 2          Cheesy Low-Carb Omelet      keto         chinese
# 3                      Angel Eggs      keto  middle eastern
# 4  Roasted Onions And Green Beans      keto          kosher
#
#    total_time_in_minutes  calories   fat  carbs  protein
# 0                   45.0     437.0  38.0    8.0      8.0
# 1                   10.0     145.0   4.0    1.6      0.6
# 2                   10.0     451.0  36.0    3.0     33.0
# 3                   30.0     184.0  15.0    1.0     12.0
# 4                   25.0     214.0  19.4    3.7      8.3

# %%
# Total number of recipes in the dataset
num_recipes = df.shape[0]
print("Total number of recipes:", num_recipes)

# Unique diet types and their counts
diet_types = df['diet_type'].unique()
print("\nUnique diet types:", diet_types)
print("Count per diet type:")
print(df['diet_type'].value_counts())

# Unique cuisine types and their counts
cuisine_types = df['cuisine_type'].unique()
print("\nUnique cuisine types:", cuisine_types)
print("Count per cuisine type:")
print(df['cuisine_type'].value_counts())
# Out:
# Total number of recipes: 8294
#
# Unique diet types: ['keto' 'paleo' 'vegan' 'mediterranean' 'dash']
# Count per diet type:
# diet_type
# keto             2000
# mediterranean    1753
# dash             1745
# vegan            1522
# paleo            1274
# Name: count, dtype: int64
#
# Unique cuisine types: ['italian' 'american' 'chinese' 'middle eastern' 'kosher'
#  'south east asian' 'nordic' 'japanese' 'eastern europe' 'caribbean'
#  'central europe' 'south american' 'asian' 'french' 'mexican'
#  'mediterranean' 'british' 'world' 'indian']
# Count per cuisine type:
# cuisine_type
# american            2925
# mediterranean       1764
# italian              828
# french               627
# world                285
# british              270
# mexican              251
# nordic               182
# south east asian     170
# south american       162
# asian                152
# chinese              148
# middle eastern       121
# indian               119
# eastern europe        88
# japanese              78
# central europe        57
# caribbean             37
# kosher                30
# Name: count, dtype: int64

# %%
numeric_cols = ['total_time_in_minutes', 'calories', 'fat', 'carbs', 'protein']
print("Summary statistics for numeric columns:")
print(df[numeric_cols].describe())
# Out:
# Summary statistics for numeric columns:
#        total_time_in_minutes      calories          fat        carbs  \
# count            8294.000000   8294.000000  8293.000000  8293.000000
# mean               39.689535   1900.148797   111.519643   143.644441
# std                20.416209   1722.909031   120.777753   183.574114
# min                 0.000000      0.240000     0.000000     0.000000
# 25%                28.250000    794.260000    34.440000    29.180000
# 50%                39.000000   1532.545000    77.650000    83.670000
# 75%                50.000000   2540.202500   151.210000   196.290000
# max               630.000000  40018.000000  1930.240000  3405.550000
#
#            protein
# count  8292.000000
# mean     79.169437
# std      88.707868
# min       0.000000
# 25%      20.797500
# 50%      51.905000
# 75%     107.550000
# max    1273.610000

# %%
# Bar chart for diet_type counts
plt.figure(figsize=(8, 6))
df['diet_type'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Count of Recipes per Diet Type')
plt.xlabel('Diet Type')
plt.ylabel('Number of Recipes')
plt.tight_layout()
plt.show()

# Bar chart for cuisine_type counts
plt.figure(figsize=(10, 6))
df['cuisine_type'].value_counts().plot(kind='bar', color='coral')
plt.title('Count of Recipes per Cuisine Type')
plt.xlabel('Cuisine Type')
plt.ylabel('Number of Recipes')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
df[numeric_cols].hist(bins=20, layout=(2, 3), color='lightgreen', edgecolor='black')
plt.suptitle('Distribution of Numeric Columns')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
